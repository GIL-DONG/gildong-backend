# %%
import requests

url = 'http://211.169.248.182:5041/data-detail'
params = {'data_id': '5'}

response = requests.get(url, params=params)

print(response.text)
# Out:
# {"data":{"zipcode":"52238","overview":"경북 산청군 시천면 내공리에 있는 가고파캠핑장은 두류연수원으로 사용했던 장소이기도 하다. 전체 파쇄석이 깔린 캠핑장으로, 데크 공간이 꽤 널찍하게 마련되어 있어 캠핑 시 주변 캠핑객과의 거리를 유지할 수 있다. 다만, 일부 사이트는 땡볕이어서 원하는 사이트를 잘 고르는 것이 중요하다. 산청 가고파캠핑장은 낡고 오래되었으나, 깨끗하게 유지되고 있으며, 지나치게 크지 않은 조용한 캠핑장을 원하는 이들에게 사랑받고 있다. 또한, 아이들을 위한 트램펄린도 마련되어 있고, 샤워장도 깨끗하게 유지되고 있다. 매점에는 필요한 물품이 알차게 채워져 있으나, 가까이에 대형 마트도 있어 장보기에도 걱정이 없다. 약 396㎡ 규모로 그 넓이를 자랑하는 수영장이 마련되어 있으며, 이 수영장에는 지하수를 채우기 때문에 물이 굉장히 차가워서 여름철에는 더욱 시원하게 즐길 수 있다.","title":"가고파캠핑장","addr":"경상남도 산청군 시천면 지리산대로1478번길 31-10","url":"http://tong.visitkorea.or.kr/cms/resource/33/2799833_image2_1.JPG","contenttypeid":"음식점"}}

# %%
import requests

url = 'http://211.169.248.182:5041/users/register'
data = {
    "Email": "user@example.com",
    "age": 32,
    "age_group": 30,
    "disability_status": False,
    "disability_type": "visual",
    "gender": "남",
    "prefer_travel": ["car"],  # 이를 리스트로 변경
    "residence": {
        "lat": 37.5665,
        "lon": 126.9780
    },
    "significant": "none",
    "userID": "user123",
    "user_name": "wslee",
    "user_photo": ""  # 이 필드를 추가. 실제 값을 넣어야 합니다.
}


response = requests.post(url, json=data)

print(response.text)
# Out:
# {"message":"User registered successfully!","access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc0MjY5MjF9.fmA4oMmce-tcVPZuxsZeUijvHzsVu8XYPgr0SRvpUFo"}

# %%
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc0MjY5MjF9.fmA4oMmce-tcVPZuxsZeUijvHzsVu8XYPgr0SRvpUFo"

# %%
import requests

url = 'http://211.169.248.182:5041/convo'
params = {'session_id': '22bbfd5c-04bb-4fcc-a0dd-aed8b2e6c56f'}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

# 서버의 응답을 출력합니다.
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/pcn/RnS/test/wslee/project/gildong_test/test_for_test.ipynb 셀 4 line 6
#       <a href='vscode-notebook-cell://ssh-remote%2Bgabia/home/pcn/RnS/test/wslee/project/gildong_test/test_for_test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> url = 'http://211.169.248.182:5041/convo'
#       <a href='vscode-notebook-cell://ssh-remote%2Bgabia/home/pcn/RnS/test/wslee/project/gildong_test/test_for_test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> params = {'session_id': '8bee8382-c4ed-4889-86cf-ee2e5abceb56'}
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgabia/home/pcn/RnS/test/wslee/project/gildong_test/test_for_test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> headers = {"Authorization": f"Bearer {access_token}"}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "사진 같은곳 있어?", "session_id": None, "image_name": "20231018004715_l_2020080401000347500024081.jpg"}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '사', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '진', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '을', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': ' 기', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '반', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '으로', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': ' 분', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '석', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': '한', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': ' 결과', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': ',', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# {'message': ' 사용', 'session_id': '25429ae5-74a4-4b09-b633-8954a7b77e84'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "바다 가고 싶어", "session_id": None}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '바다를 찾아 떠나는 여행, 정말 좋은 선택이십니다! 여행을 계획하시는 날짜를 알려주시면, 더욱 자세한 여행 정보를 제공해드릴 수 있을 것 같아요. 언제쯤 여행을 계획하고 계신가요?', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': 'completed', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}

# %%
session_id = '8f4bb960-179a-4076-811f-d45fb9597bb5'

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "다음주 주말에 갈거야", "session_id": session_id}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '다음주 주말에 바다로 떠나는 여행, 정말 기대되네요! 여행의 성격은 어떤 것을 원하시나요? 예를 들어, 휴식을 취하며 조용히 시간을 보내고 싶으신지, 아니면 액티비티를 즐기며 신나게 보내고 싶으신지요?', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': 'completed', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "조용한 시간을 보내고 싶어 일정 만들어줘", "session_id": session_id}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '조용한 시간을 보내고 싶으신 여행을 위해 최적의 일정을 준비하겠습니다. 특별히 고려해야 할 사항이 있으신가요?', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': 'completed', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "네가 알아서 해줘", "session_id": session_id}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '조', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '용', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '한', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 시', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '간', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '을', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 보', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '내', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '고', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 싶', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '으', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '신', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "이걸로 일정 만들어줘", "session_id": session_id}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '네', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ',', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 알', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '겠', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '습니다', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '.', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 바', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '다', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '를', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': ' 바', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '라', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# {'message': '보', 'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5'}
# ...

# %%
import requests

url = 'http://211.169.248.182:5041/itinerary/registration'
params = {'itinerary_id': "76bbf0ab-b9e7-41e9-8816-da55f4b20037"}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

print(response.text)
# Out:
# {"message":"Itinerary registered successfully."}

# %%
import requests

url = 'http://211.169.248.182:5041/itinerary'

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers)

json.loads(response.text)
# Out:
# {'detail': 'An error occurred.'}

# %%
import requests

url = 'http://211.169.248.182:5041/itinerary/detail'
params = {'itinerary_id': "76bbf0ab-b9e7-41e9-8816-da55f4b20037"}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

json.loads(response.text)
# Out:
# {'data': {'schedule': [{'date': '2023-10-21',
#     'date_type': 'day_label',
#     'start_time': '10:00:00',
#     'image_url': 'http://tong.visitkorea.or.kr/cms/resource/92/2488592_image2_1.jpg',
#     'end_time': '12:00:00',
#     'description': '아름다운 바다를 바라보며 조용한 산자락에서 아침을 시작하세요.',
#     'visual': False,
#     'hearing': False,
#     'location': {'lon': 126.4400240061, 'lat': 37.5288907466},
#     'title': '태림산장',
#     'physical': False,
#     'url': 'https://gildong.site/travel/detail/22926'},
#    {'date': '2023-10-21',
#     'date_type': 'day_label',
#     'start_time': '14:00:00',
#     'image_url': 'http://tong.visitkorea.or.kr/cms/resource/15/2800215_image2_1.jpg',
#     'end_time': '16:00:00',
#     'description': '투명하고 깊은 바다와 고요한 분위기를 느껴보세요. 요트를 탈 수 있는 요트장이 있습니다.',
#     'visual': False,
#     'hearing': False,
#     'location': {'lon': 126.7400446641, 'lat': 33.5580773628},
#     'title': '김녕항 / 김녕포구',
#     'physical': False,
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "2일차 저녁에 맛집으로 추가해줘", "session_id": "f59e2f7e-796a-4278-8a6a-618491a6bcbf"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '2', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '일', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '차', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 저', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '녁', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '에', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 방', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '문', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '하', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '실', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 수', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 있는', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "날씨 알려줘", "session_id": "f59e2f7e-796a-4278-8a6a-618491a6bcbf"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '오', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '늘', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 남', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '원', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '의', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 날', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '씨', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '는', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 아', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '침', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '에', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '는', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "남원흥부제 후기 알려줘", "session_id": "f59e2f7e-796a-4278-8a6a-618491a6bcbf"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '남원흥부제', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '에', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 대', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '한', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 후', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '기', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '를', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 찾', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '아', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '보', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "일정에서 남원흥부제 빼줘", "session_id": "f59e2f7e-796a-4278-8a6a-618491a6bcbf"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '네', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ',', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '남원흥부제', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '를', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 여', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '행', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 일', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '정', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': '에서', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# {'message': ' 제', 'session_id': 'f59e2f7e-796a-4278-8a6a-618491a6bcbf'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "1박 2일로 일본가고 싶어", "session_id": None}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '죄송합니다, 제 기능은 대한민국 내부의 여행에 대해 최적화되어 있어 외국 여행은 도와드리기 어려울 것 같아요. 하지만 우리나라에서도 아름답고 재미있는 여행지가 많습니다. 국내의 어떤 지역이라도 괜찮다면 추천해드릴 수 있어요!', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': 'completed', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "평양으로 가고 싶어", "session_id": '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '죄송하지만, 현재 제가 제공할 수 있는 서비스는 대한민국 내부 여행에 한정되어 있습니다. 그래서 북한, 포함해 평양에 대한 여행 정보를 제공해드리기 어렵습니다. 대신 국내에는 또 다른 매력적인 여행지가 많이 있으니, 그 중에서 추천해드릴만한 곳을 찾아보시겠어요?', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': 'completed', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "경북으로 일정 만들어줘", "session_id": '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '경상북도 여행을 원하시군요! 아름다운 경북에서 몇 일 동안 지내실 계획이신지, 여행 시작일과 종료일을 알려주시겠어요? 그리고 특별히 꼭 경험해보시고 싶은 여행 타입이나 특별한 요청 사항이 있다면 알려주세요. 예를 들어, 자연 탐방, 역사 문화 탐방, 또는 음식 투어 등일 수 있어요.', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': 'completed', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "문화 유적지나 미술관 추천해줘", "session_id": '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '경상북도 내에서 선호하는 문화 유적지와 미술관에 대한 여행 정보를 수집하는 중입니다.', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': 'completed', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/main"
data = {"question": "일정 만들어줘", "session_id": '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '경', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '상', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '북', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '도', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 여', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '행', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '이', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '시', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '군', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '요', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ',', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 기', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# ...

# %%
import requests

url = 'http://211.169.248.182:5041/users/register'
data = {
    "Email": "user@example.com",
    "age": 32,
    "age_group": 30,
    "disability_status": False,
    "disability_type": "visual",
    "gender": "남",
    "prefer_travel": [], 
    "residence": {
        "lat": 37.5665,
        "lon": 126.9780
    },
    "significant": "none",
    "userID": "user123",
    "user_name": "wslee",
    "user_photo": ""  # 이 필드를 추가. 실제 값을 넣어야 합니다.
}


response = requests.post(url, json=data)

print(response.text)
# Out:
# {"message":"User registered successfully!","access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc3MTIxODR9.-fD4TWzD30YiWfbnpQ3WIHFJn6PiZeJQwqhHbqodNjY"}

# %%
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc3MTIxODR9.-fD4TWzD30YiWfbnpQ3WIHFJn6PiZeJQwqhHbqodNjY"

# %%
import requests

url = 'http://211.169.248.182:5041/itinerary/registration'
params = {'itinerary_id': "edfc0dcc-7392-4caf-bfdb-d4b8f7a5ac03"}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

print(response.text)
# Out:
# {"message":"Itinerary registered successfully."}

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "날씨 알려줘", "session_id": "3cdc2cef-e110-438a-bb55-e82a91f0ed77"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '현재', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 제', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '가', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 사용', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '자', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '님', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '의', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 여', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '행', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '지', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '인', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 경', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "경주 날씨 알려주고 1일차 점심이랑 저녁 장소 맛집으로 추가해줘", "session_id": "3cdc2cef-e110-438a-bb55-e82a91f0ed77"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '경', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '주', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '의', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 날', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '씨', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 정보', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '를', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 제', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '공', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '하는', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '데', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 문', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "다음주 경주 날씨 알려줘", "session_id": "3cdc2cef-e110-438a-bb55-e82a91f0ed77"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '다', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '음', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '주', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 경', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '주', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '의', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 날', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '씨', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '를', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': ' 알', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '려', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# {'message': '드', 'session_id': '3cdc2cef-e110-438a-bb55-e82a91f0ed77'}
# ...

# %%
import requests
import json

url = "http://211.169.248.182:5041/chatbot/member"
data = {"question": "다음달 경주 날씨 알려줘", "session_id": "3cdc2cef-e110-438a-bb55-e82a91f0ed77"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
