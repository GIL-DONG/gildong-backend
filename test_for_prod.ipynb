# %%
import requests

url = 'https://gildongserver.shop/'

response = requests.get(url)

print(response.text)
# Out:
# {"message":"API is ready!"}

# %%
import requests

url = 'https://gildongserver.shop/data-detail'
params = {'data_id': '5'}

response = requests.get(url, params=params)

print(response.text)
# Out:
# {"detail":"An error occurred."}

# %%
import requests

url = 'https://gildongserver.shop/users/register'
data = {
    "Email": "user@example.com",
    "age": 33,
    "age_group": 30,
    "disability_status": False,
    "gender": "남",
    "prefer_travel": ["car"],  # 이를 리스트로 변경
    "residence": {
        "lat": 37.5665,
        "lon": 126.9780
    },
    "significant": "none",
    "userID": "user123",
    "user_name": "ella",
    "user_photo": ""  # 이 필드를 추가. 실제 값을 넣어야 합니다.
}


response = requests.post(url, json=data)

print(response.text)
# Out:
# {"message":"User registered successfully!","access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc0NTAzNDJ9.ZZypEuga_p5A4BhRpQ3-9jeheweVa98N5u2HhgDYEIk"}

# %%
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoidXNlcjEyMyIsInRva2VuX3R5cGUiOiJhY2Nlc3MiLCJleHAiOjE2OTc0NTAzNDJ9.ZZypEuga_p5A4BhRpQ3-9jeheweVa98N5u2HhgDYEIk"

# %%
import requests

url = 'https://gildongserver.shop/convo'
params = {'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

print(response.text)
# Out:
# {"data":[{"formatted_ai_message":"전주로의 여행을 계획하시는군요! 여행을 원하시는 날짜와 특별히 원하시는 여행 경험(예: 문화, 음식, 역사 등)에 대해 알려주시면, 더욱 맞춤화된 여행 계획을 도와드릴 수 있습니다.","user_message":"전주로 가고 싶어","turn_id":1,"timestamp":"2023-10-13T04:50:16"},{"formatted_ai_message":"전주 한옥마을에서 맛있는 비빔밥을 즐기고 싶으시군요! 그럼[전북 임실군 순창체험여행](https://gildong.site/travel/detail/27451)에서 열리는2023 전주 비빔밥축제를 추천드립니다. 이 축제는 전주의 대표 미식축제로, 다양한 전주 음식문화 콘텐츠와 관광자원을 활용하여 맛과 멋이 있는 대한민국 ‘대표 음식관광축제’로 전주 맛의 길을 열어 갑니다.\n\n또한,[전라북도무형문화재 한마당축제](https://gildong.site/travel/detail/27430)에서는 전주한지문화축제를 통해 전통한지공예의 경진대회를 통해 전국의 우수공예인을 발굴하고, 전주한지 공예발전에 기여하고 있습니다. 이 축제도 한번 참여해보시는 것을 추천드립니다.\n\n이 외에도 전주에는 맛있는 비빔밥을 즐길 수 있는 다양한 식당들이 있습니다.[전라회관](https://gildong.site/travel/detail/27434)에서는 전주의 다양한 공예품을 만나보실 수 있으며,[전북 고창의 문화와 자연을 찾아서](https://gildong.site/travel/detail/27448)에서는 전주의 10가지 재료를 이용해 푸짐한 한 상 차림을 제공하는 전주밥상 다잡수소를 방문해보실 수 있습니다. 이곳에서는 보리굴비 밥상과 돼지불고기밥상이 주메뉴로 인기가 있습니다. \n\n이렇게 다양한 경험을 통해 전주의 맛과 멋을 느껴보시길 바랍니다.","user_message":"한옥마을에서 비빔밥 먹고 싶어","turn_id":2,"timestamp":"2
# ...

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "수원 관광지로 일정 만들어줘 ", "session_id": None, "image_name": None}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '수원 여행을 계획하시는군요! 여행의 시작일과 종료일을 알려주시면, 그 기간 동안의 여행 일정을 만들어드리겠습니다. 여행의 시작일과 종료일을 알려주세요.', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': 'completed', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "비슷한 명소", "session_id": None, "image_name": "20231018210234_forest-7228105_1280.png"}

with requests.post(url, json=data, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "나는 부모님을 모시고 가야해서 사람이 많이 없는 곳이면 좋겠어", "session_id": "52cdc99d-2692-49f2-814f-e4b69d99ec2c"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        print(json.loads(chunk))
# Out:
# {'message': '부모님과 함께 편안하게 여행하실 수 있도록 사람이 많이 없는 곳을 중심으로 수원 여행 일정을 계획해드리겠습니다. 추가로 고려해야 할 사항이 있으시면 알려주세요.', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': 'completed', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "엄마가 시각장애인이야", "session_id": "52cdc99d-2692-49f2-814f-e4b69d99ec2c"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        # chunk를 JSON으로 로드합니다.
        print(json.loads(chunk))
# Out:
# {'message': '엄마를 위해 시각장애인 편의 시설이 잘 갖춰진 곳을 중심으로 여행 일정을 계획해드리겠습니다. 추가로 고려해야 할 사항이 있으시면 알려주세요.', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': 'completed', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "없어 만들어줘", "session_id": "52cdc99d-2692-49f2-814f-e4b69d99ec2c"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        # chunk를 JSON으로 로드합니다.
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '"', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '수', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '원', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': ' 여', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '행', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': ' 일', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '정', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '을', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': ' 만', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '들', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '어', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# {'message': '드', 'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c'}
# ...

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "음식점 다양한 곳으로 수정해줘", "session_id": "3aeb2b80-9fe8-47d7-be41-a9829509160e"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        # chunk를 JSON으로 로드합니다.
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '네', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ',', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 전', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '주', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 여', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '행', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '에서', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 다', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '양', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '한', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 음', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '식', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# ...

# %%
import requests
import json

url = "https://gildongserver.shop/chatbot/main"
data = {"question": "2일차 전라회관 말고 다른 곳 추천해줘", "session_id": "3aeb2b80-9fe8-47d7-be41-a9829509160e"}

headers = {"Authorization": f"Bearer {access_token}"}

with requests.post(url, json=data, headers=headers, stream=True) as r:
    for chunk in r.iter_content(1024):
        # chunk를 JSON으로 로드합니다.
        print(json.loads(chunk))
# Out:
# {'message': '', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '네', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ',', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' ', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '2', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '일', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '차', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 점', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '심', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '식', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '사', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': ' 장', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# {'message': '소', 'session_id': '3aeb2b80-9fe8-47d7-be41-a9829509160e'}
# ...

# %%
import requests

url = 'https://gildongserver.shop/itinerary/registration'
params = {'itinerary_id': "f2930afd-137a-49d5-8a37-f45eaa670036"}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

print(response.text)
# Out:
# {"message":"Itinerary registered successfully."}

# %%
import requests
import json

url = 'https://gildongserver.shop/itinerary'

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers)

json.loads(response.text)
# Out:
# {'data': [{'itinerary_id': 'f2930afd-137a-49d5-8a37-f45eaa670036',
#    'session_id': '52cdc99d-2692-49f2-814f-e4b69d99ec2c',
#    'title': '수원 여행: 편안하고 안전한 여행',
#    'destinations': [{'title': '경기중앙교육도서관',
#      'physical': True,
#      'visual': True,
#      'hearing': True},
#     {'title': '광교호수공원', 'physical': True, 'visual': True, 'hearing': True},
#     {'title': '수원시티투어', 'physical': False, 'visual': False, 'hearing': False},
#     {'title': '구매탄시장', 'physical': True, 'visual': True, 'hearing': True},
#     {'title': '화성행궁', 'physical': True, 'visual': True, 'hearing': True},
#     {'title': '실크로드관광호텔',
#      'physical': False,
#      'visual': False,
#      'hearing': False}],
#    'date_type': 'date'},
#   {'itinerary_id': '76bbf0ab-b9e7-41e9-8816-da55f4b20037',
#    'session_id': '8f4bb960-179a-4076-811f-d45fb9597bb5',
#    'title': '조용한 바다를 바라보며 휴식을 취하는 여행',
#    'destinations': [{'title': '태림산장',
#      'physical': False,
#      'visual': False,
# ...

# %%
import requests

url = 'https://gildongserver.shop/itinerary/detail'
params = {'itinerary_id': "f2930afd-137a-49d5-8a37-f45eaa670036"}

headers = {"Authorization": f"Bearer {access_token}"}

response = requests.get(url, headers=headers, params=params)

json.loads(response.text)
# Out:
# {'data': {'schedule': [{'date': '2023-10-20',
#     'date_type': 'date',
#     'start_time': '14:00:00',
#     'image_url': 'http://tong.visitkorea.or.kr/cms/resource/91/1785991_image2_1.jpg',
#     'end_time': '16:00:00',
#     'description': '시각장애인 편의 시설이 잘 갖춰져 있습니다.',
#     'visual': True,
#     'hearing': True,
#     'location': {'lon': 127.0224634611, 'lat': 37.2983667056},
#     'title': '경기중앙교육도서관',
#     'physical': True,
#     'url': 'https://gildong.site/travel/detail/25207'},
#    {'date': '2023-10-21',
#     'date_type': 'date',
#     'start_time': '10:00:00',
#     'image_url': 'http://tong.visitkorea.or.kr/cms/resource/16/2719716_image2_1.jpg',
#     'end_time': '12:00:00',
#     'description': '자연을 즐길 수 있는 도심 속 호수공원입니다. 시각장애인 편의 시설이 있습니다.',
#     'visual': True,
#     'hearing': True,
#     'location': {'lon': 127.065279673, 'lat': 37.2750451718},
#     'title': '광교호수공원',
#     'physical': True,
#     'url': 'https://gildong.site/travel/detail/25436'},
# ...
